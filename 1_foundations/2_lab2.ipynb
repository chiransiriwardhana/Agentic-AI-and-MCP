# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# If you had to design a society that balances individual freedom with collective responsibility, what principles would guide your approach, and how would you address potential conflicts between personal liberties and societal needs?

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Here’s a practical, principles-based design for a society that aims to maximize individual freedom while ensuring collective responsibility. It’s a flexible framework you can adapt to different cultural, historical, and economic contexts.
#
# Core guiding principles
# - Freedom with responsibility: Individuals have core freedoms, but freedoms come with duties to others and to future generations.
# - Dignity and equality: Every person deserves basic safety, opportunity, and protection from discrimination.
# - Solidarity and inclusion: Society should extend support to those in need and actively remove barriers to participation.
# - Rule of law and accountability: Laws apply equally; power is checked by independent institutions and transparent processes.
# - Sustainability and resilience: Decisions respect long-term social, environmental, and economic impacts.
# - Participatory legitimacy: Citizens have meaningful opportunities to influence decisions that affect them.
#
# Foundational rights and duties
# - Rights: Personal autonomy, privacy, freedom of expression within non-harmful limits, association, access to essential services (healthcare, education, housing), and equal protection under the law.
# - Duties: Obey laws, contribute to public goods, respect others’ rights, participate in civic life, and act with integrity toward the community and the environment.
# - Positive rights with responsibilities: Ensure universal access to essential services and social protections, funded fairly and administered transparently.
#
# Institutional design
# - Constitutional architecture:
#   - A written constitution or charter that guarantees fundamental rights and sets out restraints on governmental power.
#   - A clear rights-enabled framework (e.g., a bill of rights with both negative and positive rights) and a proportionality test for any rights limitations.
# - Separation of powers with robust checks and balances:
#   - Legislature, independent judiciary, executive with accountable oversight, and transparent administrative agencies.
#   - Independent anti-corruption and ethics commissions, with strong whistleblower protections.
# - Independent information and deliberation:
#   - Free press and protected civic space.
#   - Public deliberation bodies (citizen assemblies, juries, deliberative polls) for major decisions.
# - Justice and accountability:
#   - Accessible, timely courts; restorative justice options where appropriate.
#   - Mechanisms for redress when rights are violated, including remedies and compensation.
# - Data, privacy, and technology governance:
#   - Clear rules on surveillance, data ownership, consent, and accountability for algorithmic decisions.
#   - Privacy safeguards as default; opt-out and transparency as standard practices.
#
# Economic and social policy mix
# - Market plus strong social supports:
#   - Mixed economy with robust competition rules, strong anti-monopoly safeguards, and public provisioning of essential services.
#   - Progressive taxation with transparent use of revenues for universal services (healthcare, education, housing, childcare, basic income or wage supports where needed).
# - Universal/near-universal services:
#   - Healthcare, education, housing supports, childcare, and basic income or guaranteed income floor to reduce insecurity.
#   - Environmental protections and climate resilience as public goods, funded by public resources and private incentives that align with sustainability.
# - Labor and mobility rights:
#   - Strong labor rights, fair wages, safe working conditions, and retraining programs for workers affected by technological change.
#   - Labor mobility within the country with portable benefits to reduce geographic inequality.
# - Housing and land use:
#   - Policies that ensure affordable housing, prevent discrimination in access, and manage land use for the common good without eroding individual property rights without just cause.
#
# Participatory and governance processes
# - Deliberative democracy and citizen participation:
#   - Regular citizen assemblies on major issues (e.g., climate, digital rights, education reform).
#   - Participatory budgeting at local levels; transparency about how decisions are funded and implemented.
# - Transparent policymaking:
#   - Clear impact assessments (economic, social, privacy, environmental) before laws are enacted.
#   - Sunset clauses and mandatory reviews for intrusive or rights-limiting measures.
# - Deliberation and conflict resolution:
#   - Systems to surface and address minority concerns, with strong anti-discrimination safeguards.
#   - Structured negotiation, mediation, and restorative justice options to resolve disputes without escalating coercion.
#
# Handling conflicts between personal liberties and societal needs
# - Foundational approach:
#   - Always start with the least restrictive means to achieve a legitimate public interest.
#   - Use a proportionality framework: necessity, suitability, and the balancing of benefits and harms.
#   - Time-bound measures with built-in sunset clauses and independent sunset reviews.
# - Processes to resolve tensions:
#   - Rights impact assessments (RIA) for proposed policies to evaluate trade-offs for different groups.
#   - Legally enshrined overrides only for clear, evidence-based reasons (public safety, health, environmental protection) with judicial review.
#   - Differential but non-discriminatory accommodations where feasible (e.g., exemptions or alternatives for vulnerable groups).
# - Safeguards for civil liberties during crises:
#   - Emergency powers that are transparent, subject to oversight, with strict duration limits, and ongoing parliamentary scrutiny.
#   - Oversight by independent bodies and active communication with the public to maintain trust.
# - Respectful public discourse:
#   - Strong protections against discrimination and hate speech while preserving robust debate and dissent.
#   - Civic education to improve understanding of trade-offs and the rationale behind measures.
#
# Implementation roadmap (phased)
# - Phase 1 (short term): Enshrine core rights and establish independent institutions; implement universal basic services pilots; begin participatory budgeting at local levels.
# - Phase 2 (medium term): Scale up social protections, pass comprehensive data/privacy laws, strengthen environmental standards, and embed deliberative mechanisms in key policy areas.
# - Phase 3 (long term): Institutionalize regular citizen assemblies for constitutional or major reforms; deepen education on civic rights and responsibilities; continually refine proportionality and sunset approaches.
#
# Metrics and accountability
# - Well-being and capabilities: Measure actual freedoms people can exercise, not just formal rights.
# - Inequality and social protection: Track access to essential services, poverty rates, and opportunity gaps.
# - Democratic health: Participation rates, trust in institutions, disparities in civic engagement.
# - Sustainability: Environmental indicators, resource use, and resilience to shocks.
# - Rights protection: Incidence of rights violations, ease of redress, and independence of oversight bodies.
#
# A few quick alternative flavors you could consider
# - Liberal-democratic with strong social provision: Emphasizes a robust safety net and active government in ensuring equal opportunity, with strong civil liberties.
# - Participatory or deliberative democracy focus: Uses citizen assemblies and direct participatory budgeting as core governance tools.
# - Capabilities-based approach: Centers on expanding real freedoms people have to do and be meaningful in life, drawing on Sen/Nussbaum frameworks.
#
# If you tell me your context (region, culture, values, current institutions, and what you see as the biggest trade-offs), I can tailor this framework into a more concrete design with specific constitutional provisions, policy proposals, and governance processes.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Resolving a conflict between two parties with valid yet opposing perspectives on a historical event involves active listening, empathy, and careful facilitation. Here's a step-by-step approach to help ensure both sides feel heard and understood:
#
# 1. Establish a neutral and non-biased facilitator: Choose someone who is not emotionally invested in either perspective and can remain impartial throughout the process.
# 2. Define the parameters of the conversation: Set clear guidelines for the discussion, such as the specific historical event in focus, the expectations for respectful dialogue, and the desired outcome (e.g., understanding, mutual respect).
#
# 3. Encourage open communication:
#    * Invite both parties to share their perspectives in an open and relaxed setting.
#    - Provide equal time for each party to express themselves without interruption or judgment.
#    * Listen attentively to each side's concerns and ask clarifying questions when necessary.
#
# 4. Use active listening skills:
#    - Maintain eye contact with the speaker and nod to show understanding.
#    - Reflect back key points to ensure comprehension (e.g., "Just to make sure I understand, you think...").
#    - Avoid interrupting and let each side complete their thoughts before responding.
#
# 5. Foster empathy through storytelling: Encourage both parties to share personal anecdotes or stories related to the historical event. This can help create a deeper emotional connection and promote understanding.
#
# 6. Explore underlying assumptions and values: Help each party recognize the emotional triggers driving their perspectives. Encourage them to acknowledge any biases and explore alternative viewpoints with an open mind.
# 7. Identify commonalities:
#    - Look for areas of agreement between the two perspectives.
#    - Emphasize shared goals or values that unite both parties.
#
# 8. Use neutral language: Refrain from using loaded language, idioms, or jargon that may exacerbate the conflict. Stick to clear and concise descriptions of events and avoid emotional appeals.
#
# 9. Develop a "bridge" between competing narratives:
#    - Identify key moments in the historical event where different perspectives emerge.
#    - Work together to develop a more nuanced understanding of these critical points by considering multiple sources, texts, and expert opinions.
#
# 10. Seek resolution through compromise:
#     * Help each party identify areas of commonality and potential areas for concession.
#     * Facilitate a collaborative process for reaching mutually beneficial solutions.
#     - Encourage creative problem-solving that considers the unique perspectives brought to the table.
#
# By following these steps, you can create an environment conducive to respectful dialogue and foster a deeper understanding between two parties with opposing views on a historical event.

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['llama3.2']
# ['Resolving a conflict between two parties with valid yet opposing perspectives on a historical event involves active listening, empathy, and careful facilitation. Here\'s a step-by-step approach to help ensure both sides feel heard and understood:\n\n1. Establish a neutral and non-biased facilitator: Choose someone who is not emotionally invested in either perspective and can remain impartial throughout the process.\n2. Define the parameters of the conversation: Set clear guidelines for the discussion, such as the specific historical event in focus, the expectations for respectful dialogue, and the desired outcome (e.g., understanding, mutual respect).\n\n3. Encourage open communication:\n   * Invite both parties to share their perspectives in an open and relaxed setting.\n   - Provide equal time for each party to express themselves without interruption or judgment.\n   * Listen attentively to each side\'s concerns and ask clarifying questions when necessary.\n\n4. Use active listening skills:\n   - Maintain eye contact with the speaker and nod to show understanding.\n   - Reflect back key points to ensure comprehension (e.g., "Just to make sure I understand, you think...").\n   - Avoid interrupting and let each side complete their thoughts before responding.\n\n5. Foster empathy through storytelling: Encourage both parties to share personal anecdotes or stories related to the historical event. This can help create a deeper emotional connection and promote understanding.\n\n6. Explore underlying assumptions and values: Help each party recognize the emotional triggers driving their perspectives. Encourage them to acknowledge any biases and explore alternative viewpoints with an open mind.\n7. Identify commonalities:\n   - Look for areas of agreement between the two perspectives.\n   - Emphasize shared goals or values that unite both parties.\n\n8. Use neutral language: Refrain from using loaded language, idioms, or jargon that may exacerbate the conflict. Stick to clear and concise descriptions of events and avoid emotional appeals.\n\n9. Develop a "bridge" between competing narratives:\n   - Identify key moments in the historical event where different perspectives emerge.\n   - Work together to develop a more nuanced understanding of these critical points by considering multiple sources, texts, and expert opinions.\n\n10. Seek resolution through compromise:\n    * Help each party identify areas of commonality and potential areas for concession.\n    * Facilitate a collaborative process for reaching mutually beneficial solutions.\n    - Encourage creative problem-solving that considers the unique perspectives brought to the table.\n\nBy following these steps, you can create an environment conducive to respectful dialogue and foster a deeper understanding between two parties with opposing views on a historical event.']

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: llama3.2
#
# Resolving a conflict between two parties with valid yet opposing perspectives on a historical event involves active listening, empathy, and careful facilitation. Here's a step-by-step approach to help ensure both sides feel heard and understood:
#
# 1. Establish a neutral and non-biased facilitator: Choose someone who is not emotionally invested in either perspective and can remain impartial throughout the process.
# 2. Define the parameters of the conversation: Set clear guidelines for the discussion, such as the specific historical event in focus, the expectations for respectful dialogue, and the desired outcome (e.g., understanding, mutual respect).
#
# 3. Encourage open communication:
#    * Invite both parties to share their perspectives in an open and relaxed setting.
#    - Provide equal time for each party to express themselves without interruption or judgment.
#    * Listen attentively to each side's concerns and ask clarifying questions when necessary.
#
# 4. Use active listening skills:
#    - Maintain eye contact with the speaker and nod to show understanding.
#    - Reflect back key points to ensure comprehension (e.g., "Just to make sure I understand, you think...").
#    - Avoid interrupting and let each side complete their thoughts before responding.
#
# 5. Foster empathy through storytelling: Encourage both parties to share personal anecdotes or stories related to the historical event. This can help create a deeper emotional connection and promote understanding.
#
# 6. Explore underlying assumptions and values: Help each party recognize the emotional triggers driving their perspectives. Encourage them to acknowledge any biases and explore alternative viewpoints with an open mind.
# 7. Identify commonalities:
#    - Look for areas of agreement between the two perspectives.
#    - Emphasize shared goals or values that unite both parties.
#
# 8. Use neutral language: Refrain from using loaded language, idioms, or jargon that may exacerbate the conflict. Stick to clear and concise descriptions of events and avoid emotional appeals.
#
# 9. Develop a "bridge" between competing narratives:
#    - Identify key moments in the historical event where different perspectives emerge.
#    - Work together to develop a more nuanced understanding of these critical points by considering multiple sources, texts, and expert opinions.
#
# 10. Seek resolution through compromise:
#     * Help each party identify areas of commonality and potential areas for concession.
#     * Facilitate a collaborative process for reaching mutually beneficial solutions.
#     - Encourage creative problem-solving that considers the unique perspectives brought to the table.
#
# By following these steps, you can create an environment conducive to respectful dialogue and foster a deeper understanding between two parties with opposing views on a historical event.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Resolving a conflict between two parties with valid yet opposing perspectives on a historical event involves active listening, empathy, and careful facilitation. Here's a step-by-step approach to help ensure both sides feel heard and understood:
#
# 1. Establish a neutral and non-biased facilitator: Choose someone who is not emotionally invested in either perspective and can remain impartial throughout the process.
# 2. Define the parameters of the conversation: Set clear guidelines for the discussion, such as the specific historical event in focus, the expectations for respectful dialogue, and the desired outcome (e.g., understanding, mutual respect).
#
# 3. Encourage open communication:
#    * Invite both parties to share their perspectives in an open and relaxed setting.
#    - Provide equal time for each party to express themselves without interruption or judgment.
#    * Listen attentively to each side's concerns and ask clarifying questions when necessary.
#
# 4. Use active listening skills:
#    - Maintain eye contact with the speaker and nod to show understanding.
#    - Reflect back key points to ensure comprehension (e.g., "Just to make sure I understand, you think...").
#    - Avoid interrupting and let each side complete their thoughts before responding.
#
# 5. Foster empathy through storytelling: Encourage both parties to share personal anecdotes or stories related to the historical event. This can help create a deeper emotional connection and promote understanding.
#
# 6. Explore underlying assumptions and values: Help each party recognize the emotional triggers driving their perspectives. Encourage them to acknowledge any biases and explore alternative viewpoints with an open mind.
# 7. Identify commonalities:
#    - Look for areas of agreement between the two perspectives.
#    - Emphasize shared goals or values that unite both parties.
#
# 8. Use neutral language: Refrain from using loaded language, idioms, or jargon that may exacerbate the conflict. Stick to clear and concise descriptions of events and avoid emotional appeals.
#
# 9. Develop a "bridge" between competing narratives:
#    - Identify key moments in the historical event where different perspectives emerge.
#    - Work together to develop a more nuanced understanding of these critical points by considering multiple sources, texts, and expert opinions.
#
# 10. Seek resolution through compromise:
#     * Help each party identify areas of commonality and potential areas for concession.
#     * Facilitate a collaborative process for reaching mutually beneficial solutions.
#     - Encourage creative problem-solving that considers the unique perspectives brought to the table.
#
# By following these steps, you can create an environment conducive to respectful dialogue and foster a deeper understanding between two parties with opposing views on a historical event.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 1 competitors.
# Each model has been given this question:
#
# How would you approach resolving a conflict between two parties who both have valid but opposing perspectives on a historical event, while ensuring that both sides feel heard and understood in the process?
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Resolving a conflict between two parties with valid yet opposing perspectives on a historical event involves active listening, empathy, and careful facilitation. Here's a step-by-step approach to help ensure both sides feel heard and understood:
#
# 1. Establish a neutral and non-biased facilitator: Choose someone who is not emotionally invested in either perspective and can remain impartial throughout the process.
# 2. Define the parameters of the conversation: Set clear guidelines for the discussion, such as the specific historical event in focus, the expectations for respectful dialogue, and the desired outcome (e.g., understanding, mutual respect).
#
# 3. Encourage open communication:
#    * Invite both parties to share their perspectives in an open and relaxed setting.
#    - Provide equal time for each party to express themselves without interruption or judgment.
#    * Listen attentively to each side's concerns and ask clarifying questions when necessary.
#
# 4. Use active listening skills:
#    - Maintain eye contact with the speaker and nod to show understanding.
#    - Reflect back key points to ensure comprehension (e.g., "Just to make sure I understand, you think...").
#    - Avoid interrupting and let each side complete their thoughts before responding.
#
# 5. Foster empathy through storytelling: Encourage both parties to share personal anecdotes or stories related to the historical event. This can help create a deeper emotional connection and promote understanding.
#
# 6. Explore underlying assumptions and values: Help each party recognize the emotional triggers driving their perspectives. Encourage them to acknowledge any biases and explore alternative viewpoints with an open mind.
# 7. Identify commonalities:
#    - Look for areas of agreement between the two perspectives.
#    - Emphasize shared goals or values that unite both parties.
#
# 8. Use neutral language: Refrain from using loaded language, idioms, or jargon that may exacerbate the conflict. Stick to clear and concise descriptions of events and avoid emotional appeals.
#
# 9. Develop a "bridge" between competing narratives:
#    - Identify key moments in the historical event where different perspectives emerge.
#    - Work together to develop a more nuanced understanding of these critical points by considering multiple sources, texts, and expert opinions.
#
# 10. Seek resolution through compromise:
#     * Help each party identify areas of commonality and potential areas for concession.
#     * Facilitate a collaborative process for reaching mutually beneficial solutions.
#     - Encourage creative problem-solving that considers the unique perspectives brought to the table.
#
# By following these steps, you can create an environment conducive to respectful dialogue and foster a deeper understanding between two parties with opposing views on a historical event.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    # model="gpt-5-mini",
    model="gpt-4o-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: llama3.2

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
